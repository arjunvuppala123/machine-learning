# %%
import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
keras.backend.backend()
# Out:
# 'tensorflow'

# %%
from keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
plt.matshow(x_train[0])
plt.matshow(x_train[1])
plt.matshow(x_train[2])
plt.matshow(x_train[3])
plt.matshow(x_train[4])
plt.matshow(x_train[5])
plt.matshow(x_train[6])
plt.matshow(x_train[7])
plt.matshow(x_train[8])
plt.matshow(x_train[9])

# %%
x_train=x_train/255
x_test=x_test/255

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation

model = Sequential()
model.add(Flatten(input_shape=[28, 28]))
model.add(Dense(20, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_12 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                15700
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                210
# =================================================================
# Total params: 15,910
# Trainable params: 15,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer="adam",
              metrics=["accuracy"])

# %%
model.fit(x_train, y_train)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.5836 - acc: 0.8033

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 1s 60us/step
# [0.4711987882614136, 0.8361]

# %%
plt.matshow(x_test[9])

# %%
yp = model.predict(x_test)
yp
# Out:
# array([[1.1211329e-05, 5.3667441e-07, 5.7042325e-06, ..., 2.7534637e-01,
#         4.6996707e-03, 6.2560654e-01],
#        [1.2637759e-03, 3.6306360e-06, 9.4905490e-01, ..., 4.5273167e-11,
#         2.4124702e-05, 8.0824347e-10],
#        [2.7205549e-05, 9.9994671e-01, 3.2859543e-06, ..., 1.9094680e-10,
#         2.7800078e-07, 1.3348999e-08],
#        ...,
#        [3.1344667e-02, 7.1349357e-05, 2.7846987e-03, ..., 8.2837540e-04,
#         8.5104668e-01, 1.1302170e-03],
#        [5.3028427e-05, 9.9694175e-01, 4.4075161e-05, ..., 3.1586918e-08,
#         8.2448844e-07, 1.1698206e-05],
#        [4.9207592e-04, 1.4592170e-04, 4.8714079e-04, ..., 1.6705389e-01,
#         2.1987619e-02, 1.8949805e-02]], dtype=float32)

# %%
import numpy as np
np.argmax(yp[0])
# Out:
# 9

# %%
class_labels = ["T-shirt/top","Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]

# %%
class_labels[np.argmax(yp[0])]
# Out:
# 'Ankle boot'
